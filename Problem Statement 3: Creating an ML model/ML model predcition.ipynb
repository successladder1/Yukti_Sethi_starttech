# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %% [markdown]
# ### Loading Dataframes

# %%
#reading training data
traindf= pd.read_excel(r'\Users\sethi\OneDrive\Desktop\Data_file.xlsx',header=2)
#reading test data
testdf= pd.read_excel(r'\Users\sethi\OneDrive\Desktop\Test_data_file.xlsx')

# %%
#displaying data - top 5 rows of the dataset using head()

traindf.head()
# Out:
#    S.No. College       Role  City type  Previous CTC  Previous job changes  \
# 0      1  Tier 1    Manager  Non-Metro         55523                     3
# 1      2  Tier 2  Executive      Metro         57081                     1
# 2      3  Tier 2  Executive      Metro         60347                     2
# 3      4  Tier 3  Executive      Metro         49010                     2
# 4      5  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
#describing the training dataset.
traindf.describe()
# Out:
#              S.No.  Previous CTC  Previous job changes  Graduation marks  \
# count  1338.000000   1338.000000           1338.000000       1338.000000
# mean    669.500000  55581.762332              2.525411         59.890882
# std     386.391641   6685.600553              1.123502         14.894696
# min       1.000000  36990.000000              1.000000         35.000000
# 25%     335.250000  50547.000000              2.000000         47.000000
# 50%     669.500000  55293.500000              3.000000         60.000000
# 75%    1003.750000  60150.500000              4.000000         73.000000
# max    1338.000000  77911.000000              4.000000         85.000000
#
#        Exp (Months)            CTC
# count   1338.000000    1338.000000
# mean      39.207025   75459.338993
# std       14.049960   12551.280263
# min       18.000000   53020.319026
# 25%       27.000000   66905.070033
# 50%       39.000000   73112.640487
# 75%       51.000000   80747.178420
# ...

# %%
#dropping 'S.No.' column as python has automatic indentation.

del traindf["S.No."]

# %%
#Displaying information about the training dataset.
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   Previous CTC          1338 non-null   int64
#  4   Previous job changes  1338 non-null   int64
#  5   Graduation marks      1338 non-null   int64
#  6   Exp (Months)          1338 non-null   int64
#  7   CTC                   1338 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 83.8+ KB

# %%
traindf.head()
# Out:
#   College       Role  City type  Previous CTC  Previous job changes  \
# 0  Tier 1    Manager  Non-Metro         55523                     3
# 1  Tier 2  Executive      Metro         57081                     1
# 2  Tier 2  Executive      Metro         60347                     2
# 3  Tier 3  Executive      Metro         49010                     2
# 4  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
#displaying summary of the dataset

traindf.describe()
# Out:
#        Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# count   1338.000000           1338.000000       1338.000000   1338.000000
# mean   55581.762332              2.525411         59.890882     39.207025
# std     6685.600553              1.123502         14.894696     14.049960
# min    36990.000000              1.000000         35.000000     18.000000
# 25%    50547.000000              2.000000         47.000000     27.000000
# 50%    55293.500000              3.000000         60.000000     39.000000
# 75%    60150.500000              4.000000         73.000000     51.000000
# max    77911.000000              4.000000         85.000000     64.000000
#
#                  CTC
# count    1338.000000
# mean    75459.338993
# std     12551.280263
# min     53020.319026
# 25%     66905.070033
# 50%     73112.640487
# 75%     80747.178420
# max    123416.994271

# %%
#Displaying first 5 rows of test data
testdf.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# 0           0         55523                     3                66  ...
# 1           1         57081                     1                84  ...
# 2           1         60347                     2                52  ...
# 3           1         49010                     2                81  ...
# 4           1         57879                     4                74  ...
#
#    Unnamed: 14   Unnamed: 15  Unnamed: 16  Unnamed: 17   Unnamed: 18  \
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#grouping data according to college tier

collegedf = traindf.groupby("College").sum()
collegedf.head()
# Out:
#          Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# College
# Tier 1       35670161                  1667             39026         25546
# Tier 2       21155512                   925             21894         14174
# Tier 3       17542725                   787             19214         12739
#
#                   CTC
# College
# Tier 1   5.035953e+07
# Tier 2   2.715483e+07
# Tier 3   2.345024e+07

# %%
#displaying data as a candlestick box plot with respect to college tier

plt.boxplot(collegedf)          #using candlestick plot
plt.title("College Tier vs CTC")   #giving title to the graph
plt.xlabel("Tier")                 #Labeling the X-Axis
plt.ylabel("CTC")                  #Labeling the Y-Axis
# Out:
# Text(0, 0.5, 'CTC')

# %%
#grouping data according to roles

roledf = traindf.groupby("Role").sum()
roledf.head()
# Out:
#            Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# Role
# Executive      59062466                  2695             63607         41906
# Manager        15305932                   684             16527         10553
#
#                     CTC
# Role
# Executive  7.605178e+07
# Manager    2.491281e+07

# %%
#displaying data as a candlestick box plot with respect to Roles

plt.boxplot(roledf)
plt.title("Role vs CTC")
plt.xlabel("Role")
plt.ylabel("CTC")
# Out:
# Text(0, 0.5, 'CTC')

# %%
#displaying data as a bar plot with respect to Graduation Marks

x = traindf["Graduation marks"]      #assigning X-Axis values
y = traindf["CTC"]                   #assigning Y-Axis values
plt.bar(x,y)                            #using bar plot to make a bargraph
plt.title("Graduation Marks vs CTC")
plt.xlabel("Marks")
plt.ylabel("CTC")
# Out:
# Text(0, 0.5, 'CTC')

# %%
#displaying data as a bar plot with respect to Experience

x = traindf["Exp (Months)"]
y = traindf["CTC"]
plt.bar(x,y)
plt.title("Experience vs CTC")
plt.xlabel("Experience (in Months)")
plt.ylabel("CTC")
# Out:
# Text(0, 0.5, 'CTC')

# %% [markdown]
# ### Converting Categorial Variables to Numerical Variables

# %%
#Converting by using get_dummies

traindf =pd.get_dummies(traindf, drop_first=True)
traindf.head()
# Out:
#    Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# 0         55523                     3                66            19
# 1         57081                     1                84            18
# 2         60347                     2                52            28
# 3         49010                     2                81            33
# 4         57879                     4                74            32
#
#             CTC  College_Tier 2  College_Tier 3  Role_Manager  \
# 0  71406.576531               0               0             1
# 1  68005.870631               1               0             0
# 2  76764.020277               1               0             0
# 3  82092.386880               0               1             0
# 4  73878.097729               0               1             0
#
#    City type_Non-Metro
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
testdf = pd.get_dummies(testdf, drop_first=True)
testdf.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp    Actual CTC  Predicted CTC  \
# 0                     3                66   19  71406.576531            NaN
# 1                     1                84   18  68005.870631            NaN
# 2                     2                52   28  76764.020277            NaN
# 3                     2                81   33  82092.386880            NaN
# 4                     4                74   32  73878.097729            NaN
#
#    ...   Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# ...

# %% [markdown]
# ### Training Linear Regression Model

# %%
#importing Linear Regression from the sklearn library

from sklearn.linear_model import LinearRegression 
reg = LinearRegression()

# %%
x = traindf.drop("CTC", axis = 1)
y = traindf["CTC"]

# %%
#fitting the data

reg.fit(x,y)
# Out:
# LinearRegression()

# %%
#predicting data

y_prd = reg.predict(x)
print("Predictions:", y_prd)
# Out:
# Predictions: [86123.93814045 65789.54652723 69941.69030152 ... 64046.07444784
#  66223.22234281 90794.94065705]

# %% [markdown]
# ### Evaluating Results

# %%
#importing Mean Squared Error Metric from sklearn library

from sklearn.metrics import mean_squared_error

# %%
#calculating and printing Mean Squared Error

print('Mean Squared Error:', mean_squared_error(y, y_prd))
# Out:
# Mean Squared Error: 61677937.0453096

# %% [markdown]
# ### Predicting

# %%
#predicting the testing model

pred = pd.concat([testdf, pd.DataFrame(y_prd, columns=["Predicted CTC"])], axis=1)

# %%
pred = predicted[["College_Tier 2", "College_Tier 3", "City type_Non-Metro", "Graduation marks", "Role_Manager", "Actual CTC", "Predicted CTC"]]

# %%
#final Result

pred.head()
# Out:
#    College_Tier 2  College_Tier 3  City type_Non-Metro  Graduation marks  \
# 0               0               0                    1                66
# 1               1               0                    0                84
# 2               1               0                    0                52
# 3               0               1                    0                81
# 4               0               1                    0                74
#
#    Role_Manager  Role_Manager    Actual CTC  Predicted CTC  Predicted CTC
# 0             1             1  71406.576531            NaN   86123.938140
# 1             0             0  68005.870631            NaN   65789.546527
# 2             0             0  76764.020277            NaN   69941.690302
# 3             0             0  82092.386880            NaN   66843.038384
# 4             0             0  73878.097729            NaN   70556.761762
